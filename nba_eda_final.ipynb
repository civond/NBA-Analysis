# %%
import pandas as pd

# %%
team_data_to_load = "Resources/archive/Team Totals.csv"
player_data_to_load = "Resources/archive/Player Totals.csv"
team_totals_df = pd.read_csv(team_data_to_load)
player_totals_df = pd.read_csv(player_data_to_load)
team_totals_df
# Out:
#       season   lg                     team abbreviation  playoffs     g  \
# 0       2022  NBA            Atlanta Hawks          ATL     False  50.0
# 1       2022  NBA           Boston Celtics          BOS     False  52.0
# 2       2022  NBA            Brooklyn Nets          BRK     False  49.0
# 3       2022  NBA            Chicago Bulls          CHI     False  49.0
# 4       2022  NBA        Charlotte Hornets          CHO     False  51.0
# ...      ...  ...                      ...          ...       ...   ...
# 1778    1947  BAA  Providence Steamrollers          PRO     False  60.0
# 1779    1947  BAA        St. Louis Bombers          STB      True  61.0
# 1780    1947  BAA          Toronto Huskies          TRH     False  60.0
# 1781    1947  BAA      Washington Capitols          WSC      True  60.0
# 1782    1947  BAA           League Average          NaN     False  60.0
#
#            mp      fg     fga  fg_percent  ...  ft_percent    orb     drb  \
# ...

# %%
team_count = len(team_totals_df["team"].unique())
team_count
# Out:
# 97

# %%
# We can change "season" to a date type
team_totals_df.dtypes
# Out:
# season            int64
# lg               object
# team             object
# abbreviation     object
# playoffs           bool
# g               float64
# mp              float64
# fg              float64
# fga             float64
# fg_percent      float64
# x3p             float64
# x3pa            float64
# x3p_percent     float64
# x2p             float64
# x2pa            float64
# x2p_percent     float64
# ft              float64
# fta             float64
# ft_percent      float64
# orb             float64
# drb             float64
# trb             float64
# ast             float64
# stl             float64
# blk             float64
# tov             float64
# pf              float64
# pts             float64
# dtype: object

# %%
team_totals_df.count()
# Out:
# season          1783
# lg              1783
# team            1783
# abbreviation    1698
# playoffs        1783
# g               1782
# mp              1593
# fg              1782
# fga             1782
# fg_percent      1782
# x3p             1340
# x3pa            1340
# x3p_percent     1340
# x2p             1782
# x2pa            1782
# x2p_percent     1782
# ft              1782
# fta             1782
# ft_percent      1782
# orb             1453
# drb             1453
# trb             1730
# ast             1782
# stl             1394
# blk             1394
# tov             1465
# pf              1782
# pts             1782
# dtype: int64

# %%
team_totals_df.isnull().sum()
# Out:
# season            0
# lg                0
# team              0
# abbreviation     85
# playoffs          0
# g                 1
# mp              190
# fg                1
# fga               1
# fg_percent        1
# x3p             443
# x3pa            443
# x3p_percent     443
# x2p               1
# x2pa              1
# x2p_percent       1
# ft                1
# fta               1
# ft_percent        1
# orb             330
# drb             330
# trb              53
# ast               1
# stl             389
# blk             389
# tov             318
# pf                1
# pts               1
# dtype: int64

# %%
team_names = team_totals_df["team"].tolist()
team_abrev_names = team_totals_df["abbreviation"].tolist()
set(team_names)
# Out:
# {'Anaheim Amigos',
#  'Anderson Packers',
#  'Atlanta Hawks',
#  'Baltimore Bullets',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Buffalo Braves',
#  'Capital Bullets',
#  'Carolina Cougars',
#  'Charlotte Bobcats',
#  'Charlotte Hornets',
#  'Chicago Bulls',
#  'Chicago Packers',
#  'Chicago Stags',
#  'Chicago Zephyrs',
#  'Cincinnati Royals',
#  'Cleveland Cavaliers',
#  'Cleveland Rebels',
#  'Dallas Chaparrals',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Denver Rockets',
#  'Detroit Falcons',
#  'Detroit Pistons',
#  'Fort Wayne Pistons',
#  'Golden State Warriors',
#  'Houston Mavericks',
#  'Houston Rockets',
#  'Indiana Pacers',
#  'Indianapolis Jets',
#  'Indianapolis Olympians',
#  'Kansas City Kings',
#  'Kansas City-Omaha Kings',
#  'Kentucky Colonels',
#  'League Average',
#  'Los Angeles Clippers',
#  'Los Angeles Lakers',
#  'Los Angeles Stars',
#  'Memphis Grizzlies',
#  'Memphis Pros',
#  'Memphis Sounds',
#  'Memphis Tams',
#  'Miami Floridians',
# ...

# %%
player_totals_df
# Out:
#        seas_id  season  player_id          player  birth_year  pos   age  \
# 0        29648    2022       4219    Aaron Gordon         NaN   PF  26.0
# 1        29649    2022       4899     Aaron Henry         NaN   SF  22.0
# 2        29650    2022       4582   Aaron Holiday         NaN   PG  25.0
# 3        29651    2022       4805   Aaron Nesmith         NaN   SF  22.0
# 4        29652    2022       4900   Aaron Wiggins         NaN   SG  23.0
# ...        ...     ...        ...             ...         ...  ...   ...
# 30291      200    1947        157     Walt Miller         NaN    F  31.0
# 30292      201    1947        158   Warren Fenley         NaN    F  24.0
# 30293      202    1947        159   Wilbert Kautz         NaN  G-F  31.0
# 30294      203    1947        160  Woody Grimshaw         NaN    G  27.0
# 30295      204    1947        161     Wyndol Gray         NaN  G-F  24.0
#
#        experience   lg   tm  ...  ft_percent   orb    drb    trb    ast   stl  \
# ...

# %%
player_totals_df.dtypes
# Out:
# seas_id           int64
# season            int64
# player_id         int64
# player           object
# birth_year      float64
# pos              object
# age             float64
# experience        int64
# lg               object
# tm               object
# g               float64
# gs              float64
# mp              float64
# fg              float64
# fga             float64
# fg_percent      float64
# x3p             float64
# x3pa            float64
# x3p_percent     float64
# x2p             float64
# x2pa            float64
# x2p_percent     float64
# e_fg_percent    float64
# ft              float64
# fta             float64
# ft_percent      float64
# orb             float64
# drb             float64
# trb             float64
# ast             float64
# stl             float64
# blk             float64
# tov             float64
# pf              float64
# pts             float64
# dtype: object

# %%
player_totals_df.isnull().sum()
# Out:
# seas_id             0
# season              0
# player_id           0
# player              0
# birth_year      27429
# pos                 0
# age                24
# experience          0
# lg                  0
# tm                  0
# g                  29
# gs               8641
# mp               1134
# fg                 45
# fga                47
# fg_percent        190
# x3p              6354
# x3pa             6354
# x3p_percent     10451
# x2p                45
# x2pa               47
# x2p_percent       264
# e_fg_percent      190
# ft                 45
# fta                45
# ft_percent       1236
# orb              4659
# drb              4659
# trb               963
# ast                47
# stl              5638
# blk              5637
# tov              5637
# pf                 45
# pts                45
# dtype: int64

# %%
team_totals_df.count()
# Out:
# season          1783
# lg              1783
# team            1783
# abbreviation    1698
# playoffs        1783
# g               1782
# mp              1593
# fg              1782
# fga             1782
# fg_percent      1782
# x3p             1340
# x3pa            1340
# x3p_percent     1340
# x2p             1782
# x2pa            1782
# x2p_percent     1782
# ft              1782
# fta             1782
# ft_percent      1782
# orb             1453
# drb             1453
# trb             1730
# ast             1782
# stl             1394
# blk             1394
# tov             1465
# pf              1782
# pts             1782
# dtype: int64

# %%
player_totals_df.count()
# Out:
# seas_id         30296
# season          30296
# player_id       30296
# player          30296
# birth_year       2867
# pos             30296
# age             30272
# experience      30296
# lg              30296
# tm              30296
# g               30267
# gs              21655
# mp              29162
# fg              30251
# fga             30249
# fg_percent      30106
# x3p             23942
# x3pa            23942
# x3p_percent     19845
# x2p             30251
# x2pa            30249
# x2p_percent     30032
# e_fg_percent    30106
# ft              30251
# fta             30251
# ft_percent      29060
# orb             25637
# drb             25637
# trb             29333
# ast             30249
# stl             24658
# blk             24659
# tov             24659
# pf              30251
# pts             30251
# dtype: int64

# %%
player_totals_df.dtypes
# Out:
# seas_id           int64
# season            int64
# player_id         int64
# player           object
# birth_year      float64
# pos              object
# age             float64
# experience        int64
# lg               object
# tm               object
# g               float64
# gs              float64
# mp              float64
# fg              float64
# fga             float64
# fg_percent      float64
# x3p             float64
# x3pa            float64
# x3p_percent     float64
# x2p             float64
# x2pa            float64
# x2p_percent     float64
# e_fg_percent    float64
# ft              float64
# fta             float64
# ft_percent      float64
# orb             float64
# drb             float64
# trb             float64
# ast             float64
# stl             float64
# blk             float64
# tov             float64
# pf              float64
# pts             float64
# dtype: object
