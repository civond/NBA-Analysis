# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
df = pd.read_csv('Resources/final_nba_player_dataset.csv')
df = df[df['season'].between(1984,2020)]

players = df[['season','player','team','abbreviation']]

df = df.drop(['Unnamed: 0','season','player','team','abbreviation','league','season_id','player_id','games_started'],axis=1)
df.head()
# Out:
#      one_team_during_season  left_due_to_trade_during_season  \
# 624                       1                                0
# 625                       1                                0
# 626                       1                                0
# 627                       1                                0
# 628                       1                                0
#
#      joined_due_to_trade_during_season  player_efficiency_rating  \
# 624                                  0                      15.1
# 625                                  0                      11.6
# 626                                  0                      11.3
# 627                                  0                       8.2
# 628                                  0                       6.1
#
#      true_shooting_percentage  three_point_attempt_rate  \
# 624                     0.516                     0.309
# 625                     0.521                     0.393
# 626                     0.591                     0.487
# 627                     0.538                     0.536
# 628                     0.502                     0.663
#
#      free_throw_attempt_rate  offensive_rebound_percentage  \
# 624                    0.292                           5.5
# 625                    0.155                           1.5
# 626                    0.251                           1.8
# 627                    0.143                           6.6
# 628                    0.163                           2.0
#
#      defensive_rebound_percentage  total_rebound_percentage  ...  \
# 624                          20.3                      12.7  ...
# 625                           9.0                       5.3  ...
# 626                          10.6                       6.4  ...
# 627                           3.1                       4.9  ...
# 628                          12.4                       7.0  ...
#
#      defensive_rebounds  total_rebounds  assists  steals  blocks  turnovers  \
# 624               368.0           475.0    228.0    51.0    39.0      100.0
# 625               134.0           156.0    225.0    55.0    16.0       88.0
# 626                86.0           100.0     38.0    23.0    20.0       43.0
# 627                 3.0            10.0      4.0     4.0     0.0        2.0
# 628                40.0            47.0     15.0     8.0     4.0        7.0
#
#      personal_fouls  points  strength_of_schedule  playoffs
# 624           125.0   894.0                  0.09      True
# 625           120.0   627.0                 -0.33      True
# 626            78.0   345.0                  0.34      True
# 627            17.0    32.0                 -0.93     False
# 628            50.0    99.0                 -0.57     False
#
# [5 rows x 46 columns]

# %%
players.head()
# Out:
#      season             player                   team abbreviation
# 624    2020       Aaron Gordon          Orlando Magic          ORL
# 625    2020      Aaron Holiday         Indiana Pacers          IND
# 626    2020        Abdel Nader  Oklahoma City Thunder          OKC
# 627    2020        Adam Mokoka          Chicago Bulls          CHI
# 628    2020  Admiral Schofield     Washington Wizards          WAS

# %%
le = LabelEncoder()

X = df.drop('playoffs', axis=1)
X = pd.get_dummies(X)

# Create our target
y = df['playoffs'].ravel()
#y.describe()

# %%
X.describe()
# Out:
#        one_team_during_season  left_due_to_trade_during_season  \
# count            17655.000000                     17655.000000
# mean                 0.808043                         0.103030
# std                  0.393851                         0.304007
# min                  0.000000                         0.000000
# 25%                  1.000000                         0.000000
# 50%                  1.000000                         0.000000
# 75%                  1.000000                         0.000000
# max                  1.000000                         1.000000
#
#        joined_due_to_trade_during_season  player_efficiency_rating  \
# count                       17655.000000              17655.000000
# mean                            0.094874                 12.561807
# std                             0.293049                  6.444214
# min                             0.000000                -90.600000
# 25%                             0.000000                  9.700000
# 50%                             0.000000                 12.800000
# 75%                             0.000000                 15.800000
# max                             1.000000                133.800000
#
#        true_shooting_percentage  three_point_attempt_rate  \
# count              17655.000000              17655.000000
# mean                   0.507552                  0.189182
# std                    0.100360                  0.203947
# min                    0.000000                  0.000000
# 25%                    0.476000                  0.007000
# 50%                    0.520000                  0.113000
# 75%                    0.556000                  0.333000
# max                    1.500000                  1.000000
#
#        free_throw_attempt_rate  offensive_rebound_percentage  \
# count             17655.000000                  17655.000000
# mean                  0.313824                      6.012229
# std                   0.237801                      4.964732
# min                   0.000000                      0.000000
# 25%                   0.190000                      2.400000
# 50%                   0.279000                      4.900000
# 75%                   0.389000                      8.900000
# max                   6.000000                    100.000000
#
#        defensive_rebound_percentage  total_rebound_percentage  ...  \
# count                  17655.000000              17655.000000  ...
# mean                      13.987862                  9.999496  ...
# std                        6.632617                  5.023051  ...
# min                        0.000000                  0.000000  ...
# 25%                        9.200000                  6.100000  ...
# 50%                       13.000000                  9.100000  ...
# 75%                       18.200000                 13.400000  ...
# max                      100.000000                 86.400000  ...
#
#              blocks     turnovers  personal_fouls        points  \
# count  17655.000000  17655.000000    17655.000000  17655.000000
# mean      23.896743     69.722402      104.550552    482.707901
# std       35.752113     65.399664       79.134751    479.911725
# min        0.000000      0.000000        0.000000      0.000000
# 25%        3.000000     16.000000       33.000000     91.000000
# 50%       11.000000     52.000000       95.000000    333.000000
# 75%       29.000000    106.000000      164.000000    744.000000
# max      456.000000    464.000000      386.000000   3041.000000
#
#        strength_of_schedule    position_C   position_PF   position_PG  \
# count          17655.000000  17655.000000  17655.000000  17655.000000
# mean               0.009499      0.201926      0.210535      0.198244
# std                0.405375      0.401449      0.407700      0.398688
# min               -1.030000      0.000000      0.000000      0.000000
# 25%               -0.290000      0.000000      0.000000      0.000000
# 50%                0.010000      0.000000      0.000000      0.000000
# 75%                0.310000      0.000000      0.000000      0.000000
# max                1.170000      1.000000      1.000000      1.000000
#
#         position_SF   position_SG
# count  17655.000000  17655.000000
# mean       0.187822      0.201473
# std        0.390581      0.401112
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max        1.000000      1.000000
#
# [8 rows x 49 columns]

# %%
Counter(y)
# Out:
# Counter({True: 9672, False: 7983})

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=1)
Counter(y_train)
# Out:
# Counter({False: 5551, True: 6807})

# %%
df.head()
# Out:
#      one_team_during_season  left_due_to_trade_during_season  \
# 624                       1                                0
# 625                       1                                0
# 626                       1                                0
# 627                       1                                0
# 628                       1                                0
#
#      joined_due_to_trade_during_season  player_efficiency_rating  \
# 624                                  0                      15.1
# 625                                  0                      11.6
# 626                                  0                      11.3
# 627                                  0                       8.2
# 628                                  0                       6.1
#
#      true_shooting_percentage  three_point_attempt_rate  \
# 624                     0.516                     0.309
# 625                     0.521                     0.393
# 626                     0.591                     0.487
# 627                     0.538                     0.536
# 628                     0.502                     0.663
#
#      free_throw_attempt_rate  offensive_rebound_percentage  \
# 624                    0.292                           5.5
# 625                    0.155                           1.5
# 626                    0.251                           1.8
# 627                    0.143                           6.6
# 628                    0.163                           2.0
#
#      defensive_rebound_percentage  total_rebound_percentage  ...  \
# 624                          20.3                      12.7  ...
# 625                           9.0                       5.3  ...
# 626                          10.6                       6.4  ...
# 627                           3.1                       4.9  ...
# 628                          12.4                       7.0  ...
#
#      defensive_rebounds  total_rebounds  assists  steals  blocks  turnovers  \
# 624               368.0           475.0    228.0    51.0    39.0      100.0
# 625               134.0           156.0    225.0    55.0    16.0       88.0
# 626                86.0           100.0     38.0    23.0    20.0       43.0
# 627                 3.0            10.0      4.0     4.0     0.0        2.0
# 628                40.0            47.0     15.0     8.0     4.0        7.0
#
#      personal_fouls  points  strength_of_schedule  playoffs
# 624           125.0   894.0                  0.09      True
# 625           120.0   627.0                 -0.33      True
# 626            78.0   345.0                  0.34      True
# 627            17.0    32.0                 -0.93     False
# 628            50.0    99.0                 -0.57     False
#
# [5 rows x 46 columns]

# %% [markdown]
# # Balanced Random Forest

# %%
from sklearn.preprocessing import StandardScaler
#from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create a random forest classifier.
rf_model = BalancedRandomForestClassifier(n_estimators=128, random_state=1) 

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)
predictions = rf_model.predict(X_test_scaled)

# %%
#Apply model to whole dataset
predict=rf_model.predict(X)
df['preds'] = predict

#merge with players_df
players = pd.merge(players, df, how='left',left_index=True, right_index=True)
players.to_csv('Resources/balanced_forest_predictions.csv', index=False)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# Calculating the confusion matrix.
cm = confusion_matrix(y_test, predictions)

y_pred = rf_model.predict(X_test)
confusion_matrix(y_test, y_pred)

#print(cm)
# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0         1879          553
# Actual 1          671         2194

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)

print(acc_score)
# Out:
# 0.7689258070606003

# %%
# Print the imbalanced classification report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.74      0.77      0.75      2432
#         True       0.80      0.77      0.78      2865
#
#     accuracy                           0.77      5297
#    macro avg       0.77      0.77      0.77      5297
# weighted avg       0.77      0.77      0.77      5297

# %%
# List the features sorted in descending order by feature importance
importances = rf_model.feature_importances_
importances
# We can sort the features by their importance.
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.13531788381029036, 'strength_of_schedule'),
#  (0.06255762269104137, 'win_shares_per_48_min'),
#  (0.05099135485062555, 'defensive_win_shares'),
#  (0.04028614862414015, 'defensive_box_plus/minus'),
#  (0.02883057317278526, 'win_shares'),
#  (0.02813575482989428, 'player_efficiency_rating'),
#  (0.02453804810075892, 'defensive_rebounds'),
#  (0.024137879502867922, 'usage_percentage'),
#  (0.023474848171650714, 'games'),
#  (0.02310585316202718, 'defensive_rebound_percentage'),
#  (0.022707172964611014, 'box_plus/minus'),
#  (0.02175286425939203, 'minutes_played'),
#  (0.02174659628926682, 'true_shooting_percentage'),
#  (0.021671509987881105, 'total_rebounds'),
#  (0.020987956077873484, 'offensive_box_plus/minus'),
#  (0.019402874942155264, 'total_rebound_percentage'),
#  (0.019317508095611436, 'age'),
#  (0.0190438209549001, 'free_throw_attempt_rate'),
#  (0.018490691936603583, 'assist_percentage'),
#  (0.01824277109536744, 'steals'),
#  (0.01811670767204983, 'personal_fouls'),
#  (0.017896254681437924, 'steal_percentage'),
#  (0.01747699096722323, 'two_point_attempts'),
#  (0.017434771639018663, 'offensive_win_shares'),
#  (0.017373816459548608, 'freethrows_attempted'),
#  (0.01722134246952529, 'experience'),
#  (0.017177832434688723, 'offensive_rebounds'),
#  (0.01712951450689792, 'offensive_rebound_percentage'),
#  (0.0170384515751753, 'points'),
#  (0.01703793913127304, 'turnovers'),
#  (0.016681184454181194, 'fieldgoals_attemped'),
#  (0.016636044642708986, 'freethrows_made'),
#  (0.016380475992035418, 'assists'),
#  (0.01584101385301265, 'block_percentage'),
#  (0.015530811270210089, 'three_point_attempt_rate'),
#  (0.015433266150623034, 'two_point_made'),
#  (0.015134463836596229, 'fieldgoals'),
#  (0.014852685241710531, 'blocks'),
#  (0.013841199697043205, 'three_point_attempts'),
#  (0.013131010251686507, 'value_over_replacement_plyr'),
#  (0.01078292869646195, 'three_points_made'),
#  (0.0028163838368399333, 'one_team_during_season'),
#  (0.00239909437386486, 'position_SF'),
#  (0.0023036956673126293, 'joined_due_to_trade_during_season'),
#  (0.0021922593711996147, 'left_due_to_trade_during_season'),
#  (0.0021144383952023775, 'position_PF'),
#  (0.002101202836702015, 'position_SG'),
#  (0.0016474734994836873, 'position_C'),
#  (0.0015370128765425021, 'position_PG')]

# %% [markdown]
# # Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier

# Create a easy ensemble classifier
ada_model = EasyEnsembleClassifier(n_estimators=128, random_state=1) 

# Fitting the model
ada_model = ada_model.fit(X_train_scaled, y_train)
predictions = ada_model.predict(X_test_scaled)

# %%
# Calculated the balanced accuracy score
y_pred2 = ada_model.predict(X_test)
confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[1879  553]
#  [ 671 2194]]

# %%
# Display the confusion matrix
acc_score = accuracy_score(y_test, predictions)

print(acc_score)
# Out:
# 0.7611855767415519

# %%
# Print the imbalanced classification report

print(classification_report_imbalanced(y_test, predictions))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#       False       0.72      0.78      0.75      0.75      0.76      0.58      2432
#        True       0.80      0.75      0.78      0.77      0.76      0.58      2865
#
# avg / total       0.76      0.76      0.76      0.76      0.76      0.58      5297
